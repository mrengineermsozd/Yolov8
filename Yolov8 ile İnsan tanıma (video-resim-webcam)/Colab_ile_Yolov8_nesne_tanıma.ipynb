# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.91 🚀 Python-3.10.12 torch-2.4.0+cu121 CPU (Intel Xeon 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 32.8/107.7 GB disk)

# %%
# Clone ultralytics repo
# !git clone https://github.com/ultralytics/ultralytics
# %pip install -qe ultralytics
# Out:
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 40232, done.
# remote: Counting objects: 100% (928/928), done.
# remote: Compressing objects: 100% (619/619), done.
# remote: Total 40232 (delta 560), reused 576 (delta 306), pack-reused 39304 (from 1)
# Receiving objects: 100% (40232/40232), 31.20 MiB | 2.90 MiB/s, done.
# Resolving deltas: 100% (29621/29621), done.
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#   Building editable for ultralytics (pyproject.toml) ... done

# %%
# Run inference on an image with YOLOv8n
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.25 source='https://ultralytics.com/images/zidane.jpg'
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8n.pt to 'yolov8n.pt'...
# 100% 6.25M/6.25M [00:00<00:00, 168MB/s]
# Ultralytics YOLOv8.2.91 🚀 Python-3.10.12 torch-2.4.0+cu121 CPU (Intel Xeon 2.20GHz)
# YOLOv8n summary (fused): 168 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# Downloading https://ultralytics.com/images/zidane.jpg to 'zidane.jpg'...
# 100% 49.2k/49.2k [00:00<00:00, 9.21MB/s]
# image 1/1 /content/zidane.jpg: 384x640 2 persons, 1 tie, 292.8ms
# Speed: 14.9ms preprocess, 292.8ms inference, 36.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
